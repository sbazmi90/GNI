# %% [markdown]
# ## Forward Euler

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('data.txt')

# %%
m = data[:,0]
xi = data[:,1]
yi = data[:,2]
zi = data[:,3]
vxi = data[:,4]
vyi = data[:,5]
vzi = data[:,6]
t_max = 1000
G = 2.95 * (10**-4)
delta =1
N = 365000
UE = np.zeros((N-1),float)
KE = np.zeros((N-1),float)

# %%
x = np.zeros((N,10),float)
y = np.zeros((N,10),float)
z = np.zeros((N,10),float)
dx =np.zeros((10,10),float)
dy = np.zeros((10,10),float)
dz = np.zeros((10,10),float)
#ux = np.zeros((N,10),float)
#uy = np.zeros((N,10),float)
#uz = np.zeros((N,10),float)
px = np.zeros((N,10),float)
py = np.zeros((N,10),float)
pz = np.zeros((N,10),float)
r = np.zeros((10,10),float)
ux = np.zeros((10),float)
uy = np.zeros((10),float)
uz = np.zeros((10),float)
ep = 1e-6

# %%
x.shape
# Out:
# (3650, 10)

# %%
for i in range(10):
    x[0,i] = xi[i]
    y[0,i] = yi[i]
    z[0,i] = zi[i]
    px[0,i] = m[i]*vxi[i]
    py[0,i] = m[i]*vyi[i]
    pz[0,i] = m[i]*vzi[i]

# %%
x[0,1]-x[0,2]
# Out:
# -0.2509892267383287

# %%
for t in range(1,N):
    for k in range(10):
        ux[k] = uy[k] = uz[k] = UE[k] = KE[k] = 0
    for i in range(10):
        KE[t-1] = KE[t-1] + 0.5 * (px[t-1,i] * px[t-1,i] + py[t-1,i] * py[t-1,i] + pz[t-1,i] * pz[t-1,i])
        for j in range(10):
            if(i != j):
                dx[i,j] = x[t-1,i]-x[t-1,j]
                dy[i,j] = y[t-1,i]-y[t-1,j]
                dz[i,j] = z[t-1,i]-z[t-1,j]
                r[i,j] = np.sqrt(dx[i,j]**2 + dy[i,j]**2 + dz[i,j]**2)
                UE[t-1]=UE[t-1] - G* m[i]*m[j] / (r[i,j]+ep)
    for i in range(10):
        for j in range(10):
            if(i != j):
                dx[i,j] = x[t-1,i]-x[t-1,j]
                dy[i,j] = y[t-1,i]-y[t-1,j]
                dz[i,j] = z[t-1,i]-z[t-1,j]
                r[i,j] = np.sqrt(dx[i,j]**2 + dy[i,j]**2 + dz[i,j]**2)
                ux[i] = ux[i]-G*m[i]*m[j]*dx[i,j]/((r[i,j]+ep)**3)
                uy[i] = uy[i]-G*m[i]*m[j]*dy[i,j]/((r[i,j]+ep)**3)
                uz[i] = uz[i]-G*m[i]*m[j]*dz[i,j]/((r[i,j]+ep)**3)
    for l in range(10):
            x[t,l] = x[t-1,l] + delta*px[t-1,l]/m[l]
            y[t,l] = y[t-1,l] + delta*py[t-1,l]/m[l]
            z[t,l] = z[t-1,l] + delta*pz[t-1,l]/m[l]
            px[t,l] = px[t-1,l] + delta*ux[l]
            py[t,l] = py[t-1,l] + delta*uy[l]
            pz[t,l] = pz[t-1,l] + delta*uz[l]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-ffa36277d28d> in <module>
#      17                 dy[i,j] = y[t-1,i]-y[t-1,j]
#      18                 dz[i,j] = z[t-1,i]-z[t-1,j]
# ---> 19                 r[i,j] = np.sqrt(dx[i,j]**2 + dy[i,j]**2 + dz[i,j]**2)
#      20                 ux[i] = ux[i]-G*m[i]*m[j]*dx[i,j]/((r[i,j]+ep)**3)
#      21                 uy[i] = uy[i]-G*m[i]*m[j]*dy[i,j]/((r[i,j]+ep)**3)
#
# KeyboardInterrupt:

# %%
x.shape
# Out:
# (3650, 10)

# %%
xsun = x[:,0];ysun = y[:,0];zsun = z[:,0];
xmer = x[:,1];ymer = y[:,1];zmer = z[:,1];
xven = x[:,2];yven = y[:,2];zven = z[:,2];
xear = x[:,3];year = y[:,3];zear = z[:,3];
xmar = x[:,4];ymar = y[:,4];zmar = z[:,4];
xjup = x[:,5];yjup = y[:,5];zjup = z[:,5];
xsat = x[:,6];ysat = y[:,6];zsat = z[:,6];
xura = x[:,7];yura = y[:,7];zura = z[:,7];  
xnep = x[:,8];ynep = y[:,8];znep = z[:,8];                                     
xplo = x[:,9];yplo = y[:,9];zplo = z[:,9];

# %%
from mpl_toolkits import mplot3d
fig = plt.figure(figsize=(20,10))
ax = plt.axes(projection='3d')
ax.plot3D(xsun,ysun,zsun,'red')
#ax.plot3D(xmer,ymer,zmer,'black')
#ax.plot3D(xven,yven,zven,'')
ax.plot3D(xear,year,zear,'blue')
#ax.plot3D(xmar,ymar,zmar,'brown')
#ax.plot3D(xjup,yjup,zjup,'green')
#ax.plot3D(xsat,ysat,zsat,'violet')
#ax.plot3D(xura,yura,zura,'pink')
#ax.plot3D(xnep,ynep,znep,'orange')
#ax.plot3D(xplo,yplo,zplo,'gray')

# %%
px.shape

# %%
for t in range(t_max):
    for i in range(10):
        for j in range(10):
            if (i == j):
                print('')
            else:
                dx = x[i] - x[j]
                dy = y[i] - y[j]
                dz = z[i] - z[j]
                r = np.sqrt(dx**2 + dy**2 + dz**2)
                r3 = r**3
                u[i] = u[i] - G*m[i]*m[j]/r
                px[i,j] = px[i,j] - (G*m[i]*m[j]*(x[i]-x[j]))/(r3)
                py[i,j] = py[i,j] - (G*m[i]*m[j]*(y[i]-y[j]))/(r3)
                pz[i,j] = pz[i,j] - (G*m[i]*m[j]*(z[i]-z[j]))/(r3)
        k[i] = k[i] + 0.5*(px[i,j]**2 + px[i,j]**2 + pz[i,j]**2)
    for i in range(10):
        x[i] = x[i] + delta*px[i]/m[i]
        y[i] = y[i] + delta*py[i]/m[i]
        z[i] = z[i] + delta*pz[i]/m[i]
        px[i] = px[i] + delta*px[i]/m[i]
        py[i] = px[i] + delta*px[i]/m[i]
        pz[i] = px[i] + delta*px[i]/m[i]
# Out:
# /home/saman/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in true_divide
#   if sys.path[0] == '':
# /home/saman/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in true_divide
#   del sys.path[0]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-f9cf48e1fc9e> in <module>
#      11                 r3 = r**3
#      12                 u[i] = u[i] - G*m[i]*m[j]/r
# ---> 13                 px[i,j] = px[i,j] - (G*m[i]*m[j]*(x[i]-x[j]))/(r3)
#      14                 py[i,j] = py[i,j] - (G*m[i]*m[j]*(y[i]-y[j]))/(r3)
#      15                 pz[i,j] = pz[i,j] - (G*m[i]*m[j]*(z[i]-z[j]))/(r3)
#
# ValueError: setting an array element with a sequence.

# %%
x[5]
# Out:
# nan
