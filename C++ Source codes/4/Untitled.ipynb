# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
O1 = np.loadtxt("Object1.txt")
O2 = np.loadtxt("Object2.txt")
O3 = np.loadtxt("Object3.txt")
O4 = np.loadtxt("Object4.txt")
O5 = np.loadtxt("Object5.txt")
O6 = np.loadtxt("Object6.txt")
O7 = np.loadtxt("Object7.txt")
O8 = np.loadtxt("Object8.txt")
O9 = np.loadtxt("Object9.txt")
O10 = np.loadtxt("Object10.txt")
H = np.loadtxt("Energy.txt")

# %%
o1x = O1[:,1]
o1y = O1[:,2]

o2x = O2[:,1]
o2y = O2[:,2]

o3x = O3[:,1]
o3y = O3[:,2]

o4x = O4[:,1]
o4y = O4[:,2]

o5x = O5[:,1]
o5y = O5[:,2]

o6x = O6[:,1]
o6y = O6[:,2]

o7x = O7[:,1]
o7y = O7[:,2]

o8x = O8[:,1]
o8y = O8[:,2]

o9x = O9[:,1]
o9y = O9[:,2]

o10x = O10[:,1]
o10y = O10[:,2]

t = H[:,0]
px = H[:,1]
py = H[:,2]
lz = H[:,3]
E = H[:,4]

# %%
plt.figure(figsize=(20,20))
plt.plot(o1x,o1y,color = "blue")
plt.plot(o2x,o2y,color = "green")
plt.plot(o3x,o3y,color = "pink")
plt.plot(o4x,o4y,color = "orange")
plt.plot(o5x,o5y,color = "red")
plt.plot(o6x,o6y,color = "brown")
plt.plot(o7x,o7y,color = "black")
plt.plot(o8x,o8y,color = "gray")
plt.plot(o9x,o9y,color = "blue")
plt.plot(o10x,o10y, color = "blue")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Polar Vortex Stability (N = 10, t = 180 d)")
plt.savefig("pv4.png")

# %%
plt.figure(figsize=(20,10))
plt.plot(t,px)
plt.xlabel("time = 180 d")
plt.ylabel("px")
plt.title("Momentum in x direction")
plt.savefig("px4.png")

# %%
plt.figure(figsize=(20,10))
plt.plot(t,py)
plt.xlabel("time = 180 d")
plt.ylabel("py")
plt.title("Momentum in y direction")
plt.savefig("py4.png")

# %%
plt.figure(figsize=(20,10))
plt.plot(t,lz)
plt.xlabel("time = 180 d")
plt.ylabel("lz")
plt.title("Angular Momentum in direction")
plt.savefig("lz4.png")

# %%
plt.figure(figsize=(20,10))
plt.plot(t,E)
plt.xlabel("time = 180 d")
plt.ylabel("E")
plt.title("Energy")
plt.xlim(0,2160)
plt.savefig("E4.png")
